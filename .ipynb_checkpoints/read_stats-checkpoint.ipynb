# %%
import json

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
with open('../output/bbbc021/stats.txt') as f:
    lines = f.readlines()

# %%
statlines = []
for line in lines:
    if line[0] == '{':
        statlines.append(json.loads(line))

# %%
try: 
    ep = [b['ep'] for b in statlines] 
except:pass
try: 
    st = [b['st'] for b in statlines] 
except:pass
try: 
    lr = [b['lr'] for b in statlines] 
except:pass
try: 
    t = [b['t'] for b in statlines] 
except:pass
try: 
    stdr = [b['stdr'] for b in statlines] 
except:pass
try: 
    stde = [b['stde'] for b in statlines] 
except:pass
try: 
    corr = [b['corr'] for b in statlines] 
except:pass
try: 
    core = [b['core'] for b in statlines] 
except:pass
try: 
    inv_l = [b['inv_l'] for b in statlines] 
except:pass
try: 
    var_l = [b['var_l'] for b in statlines] 
except:pass
try: 
    cov_l = [b['cov_l'] for b in statlines] 
except:pass
try: 
    minv_l = [b['minv_l'] for b in statlines] 
except:pass
try: 
    mvar_l = [b['mvar_l'] for b in statlines] 
except:pass
try: 
    mcov_l = [b['mcov_l'] for b in statlines] 
except:pass
try: 
    cls_l = [b['cls_l'] for b in statlines] 
except:pass
try: 
    top1 = [b['top1'] for b in statlines] 
except:pass
try: 
    top5 = [b['top5'] for b in statlines] 
except:pass
try: 
    l = [b['l'] for b in statlines] 
except:pass

# %%
stats = pd.DataFrame()

# %%
try: 
    stats['ep'] = ep
except:
    pass
try: 
    stats['st'] = st
except:
    pass
try: 
    stats['lr'] = lr
except:
    pass
try: 
    stats['t'] = t
except:
    pass
try: 
    stats['stdr'] = stdr
except:
    pass
try: 
    stats['stde'] = stde
except:
    pass
try: 
    stats['corr'] = corr
except:
    pass
try: 
    stats['core'] = core
except:
    pass
try: 
    stats['inv_l'] = inv_l
except:
    pass
try: 
    stats['var_l'] = var_l
except:
    pass
try: 
    stats['cov_l'] = cov_l
except:
    pass
try: 
    stats['minv_l'] = minv_l
except:
    pass
try: 
    stats['mvar_l'] = mvar_l
except:
    pass
try: 
    stats['mcov_l'] = mcov_l
except:
    pass
try: 
    stats['cls_l'] = cls_l
except:
    pass
try: 
    stats['top1'] = top1
except:
    pass
try: 
    stats['top5'] = top5
except:
    pass
try: 
    stats['l'] = l
except:
    pass

# %%
stats = stats.set_index('st')

# %%
stats.columns
# Out:
# Index(['ep', 'lr', 't', 'stdr', 'stde', 'corr', 'core', 'inv_l', 'var_l',
#        'cov_l', 'minv_l', 'mvar_l', 'mcov_l', 'l'],
#       dtype='object')

# %%
sns.set_theme(palette='pastel', style='whitegrid')

fig, axes = plt.subplots(nrows=2,ncols=2, figsize=(12,8))
sns.lineplot(data=stats['l'], ax=axes[0,0])
axes[0,0].set_title('loss', fontsize=14)
sns.lineplot(data=stats['inv_l'], ax=axes[0,1])
axes[0,1].set_title('Invariance loss', fontsize=14)
sns.lineplot(data=stats['var_l'], ax=axes[1,0])
axes[1,0].set_title('Variance loss', fontsize=14)
sns.lineplot(data=stats['cov_l'], ax=axes[1,1])
axes[1,1].set_title('Covariance loss', fontsize=14)
fig.suptitle('Training stats', fontsize=20)

plt.tight_layout()

# %%
sns.set_theme(palette='pastel', style='whitegrid')

fig, axes = plt.subplots(nrows=2,ncols=2, figsize=(12,8))
sns.lineplot(data=stats['l'], ax=axes[0,0])
axes[0,0].set_title('loss', fontsize=14)
sns.lineplot(data=stats['top1'], ax=axes[0,1])
axes[0,1].set_title('top1 accuracy', fontsize=14)
sns.lineplot(data=stats['top5'], ax=axes[1,0])
axes[1,0].set_title('top5 accuracy', fontsize=14)
sns.lineplot(data=stats['cls_l'], ax=axes[1,1])
axes[1,1].set_title('Classification loss', fontsize=14)
fig.suptitle('Training stats', fontsize=20)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.virtualenvs/pytorch/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.virtualenvs/pytorch/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.virtualenvs/pytorch/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'top1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/gantugs/working/VICReg/VICRegL_single_gpu/read_stats.ipynb Cell 12 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/home/gantugs/working/VICReg/VICRegL_single_gpu/read_stats.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> sns.lineplot(data=stats['l'], ax=axes[0,0])
#       <a href='vscode-notebook-cell:/home/gantugs/working/VICReg/VICRegL_single_gpu/read_stats.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> axes[0,0].set_title('loss', fontsize=14)
# ----> <a href='vscode-notebook-cell:/home/gantugs/working/VICReg/VICRegL_single_gpu/read_stats.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> sns.lineplot(data=stats['top1'], ax=axes[0,1])
#       <a href='vscode-notebook-cell:/home/gantugs/working/VICReg/VICRegL_single_gpu/read_stats.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> axes[0,1].set_title('top1 accuracy', fontsize=14)
#       <a href='vscode-notebook-cell:/home/gantugs/working/VICReg/VICRegL_single_gpu/read_stats.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a> sns.lineplot(data=stats['top5'], ax=axes[1,0])
#
# File ~/.virtualenvs/pytorch/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.virtualenvs/pytorch/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'top1'
