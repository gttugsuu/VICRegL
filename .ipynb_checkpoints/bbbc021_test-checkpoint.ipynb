# %%
import joblib

# %%
# %matplotlib inline
from pathlib import Path

import numpy as np
import pandas as pd
from tqdm.auto import tqdm

from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import sklearn.metrics

import scipy.linalg
import scipy.spatial.distance

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('ytick', labelsize=7)
import seaborn as sns

# %% [markdown]
# ## Load model outputs

# %%
representation_dir = Path("../output/bbbc021_from_server/representations_train/")
txts = list(representation_dir.glob("*.txt"))

# %%
with open(txts[0], "r") as f:
    a = f.readlines()
    for i in range(len(a)):
        a[i] = a[i][:-1]

# %%
df = pd.DataFrame()

# %%
for txt in tqdm(txts):
    # read associated txt file
    with open(txt, "r") as f:
        cellids = f.readlines()
        for i in range(len(cellids)):
            cellids[i] = cellids[i][:-1]
    # read representation numpy file
    numpypath = representation_dir / f"{txt.stem}.npy"
    representation = np.load(numpypath)
    # make one dataframe
    onedf = pd.DataFrame(representation)
    onedf['cellidentifier'] = cellids
    # concatenate
    df = pd.concat([df, onedf], axis=0)
# Out:
#   0%|          | 0/21242 [00:00<?, ?it/s]

# %% [markdown]
# ## Load metadata

# %%
meta = pd.read_csv("/home/gantugs/working/dino_things/dino_vgg_other/split_by_moa/meta_train.csv")

# %%
meta['cellidentifier'] = [Path(cellimgp).stem for cellimgp in meta.cellimagepaths]

# %% [markdown]
# ## merge

# %%
df = df.merge(meta, left_on='cellidentifier', right_on='cellidentifier')

# %%
df["compound_concentration"] = [df.compound[i] + "_" + str(df.concentration[i]) for i in range(df.shape[0])]

# %%
df.to_csv(representation_dir.parent / 'train_representations.csv', index=False)

# %%
feat_cols = df.columns[np.arange(768)]
meta_cols = df.columns[~df.columns.isin(feat_cols)]

# %%
df
# Out:
#                 0         1         2         3         4         5         6  \
# 0        0.504181 -0.571162 -0.685661 -0.290858  0.407656  0.067600 -0.175230
# 1       -0.002409 -0.495853 -0.063973 -0.039040  0.048696 -0.222090 -0.472222
# 2        0.169557  0.392543  0.080090  0.178614  0.362728 -0.368464 -0.864160
# 3        0.342756  0.597993 -0.251408 -0.221471  0.499281 -0.316241 -1.080872
# 4        0.217944  0.346242  0.149717  0.297181  0.205034 -0.033315 -1.084110
# ...           ...       ...       ...       ...       ...       ...       ...
# 1359472  0.462243 -1.279669  0.247413 -0.229010  0.357456  0.212684  0.197718
# 1359473  0.557372 -1.376151 -0.146905 -0.384610  0.618707  0.541524  0.673152
# 1359474  0.433421 -0.787172  0.374741 -0.090159  0.646449  0.177213 -0.222102
# 1359475  0.553123 -1.310403  0.144606 -0.182836  0.559786  0.327216  0.428232
# 1359476  0.728016 -1.335387 -0.185345 -0.237606  0.586966  0.361449  0.515368
#
# ...

# %%
from umap import UMAP

# %%
import umap.plot

# %%
from pandas.api.types import is_numeric_dtype
# a function for grouping string values
def mean_str(col):
    if is_numeric_dtype(col):
        return col.mean()
    else:
        return col.unique()[0] if col.unique().shape[0] == 1 else np.NaN

# %% [markdown]
# ## aggregate to FOV

# %%
aggregated = df.groupby(by=['platewellsite']).agg(mean_str)

# %%
umapdf = aggregated.loc[aggregated.compound!='taxol']

# %%
mapper = UMAP().fit(aggregated[feat_cols].copy())

# %%
umap.plot.points(mapper, labels=aggregated.compound_concentration, color_key_cmap='Set3')
plt.legend('off')
# plt.savefig(f'output.png')

# %%
# save umap mapper
joblib.dump(mapper, representation_dir.parent / 'train_fovwise_umapper.sav')
print('UMAP calculations are saved.')
# Out:
# UMAP calculations are saved.

# %% [markdown]
# ##### On the test

# %%
mapper = joblib.load(representation_dir.parent / 'train_fovwise_umapper.sav')

# %%
testcoords = mapper.transform(aggregated[feat_cols].copy())

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=testcoords[:,0], y=testcoords[:,1], hue=aggregated.moa, s=15)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## aggregate to well

# %%
aggregated = df.groupby(by=['platewell']).agg(mean_str)

# %%
umapdf = aggregated.loc[aggregated.compound!='taxol']

# %%
mapper = UMAP().fit(aggregated[feat_cols].copy())

# %%
umap.plot.points(mapper, labels=aggregated.compound_concentration, color_key_cmap='Set3')
plt.legend('off')
# plt.savefig(f'output.png')

# %%
# save umap mapper
joblib.dump(mapper, representation_dir.parent / 'train_wellwise_umapper.sav')
print('UMAP calculations are saved.')
# Out:
# UMAP calculations are saved.

# %% [markdown]
# ##### On the test

# %%
mapper = joblib.load(representation_dir.parent / 'train_wellwise_umapper.sav')

# %%
len(feat_cols)
# Out:
# 768

# %%
testcoords = mapper.transform(aggregated[feat_cols[:-1]].copy())

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x=testcoords[:,0], y=testcoords[:,1], hue=aggregated.moa, s=8)
plt.legend(bbox_to_anchor=(1.1, 1.1))

# %%
featdir = "/raid/data/bbbc021-DP/outputs/densenet_pretrainedw_800e_1e-2lr_64box_0.25factor/features/"
meta = pd.read_csv("/raid/data/bbbc021-DP/inputs/metadata/index.csv")

# %%
classes = meta["Compound_Concentration"].unique()
classes.sort()
classes = { classes[i]:i for i in range(len(classes))}
validation = meta[meta["replicate_use"] != "Training"]

# %%
def show_confusion_matrix(y_true, y_pred, classes):
    cm = sklearn.metrics.confusion_matrix(y_true, y_pred)
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm.T/np.sum(cm, axis=1), cmap=plt.cm.Blues)
    fig.colorbar(cax) 
    a = ax.set_yticks([x for x in classes.values()])
    b = ax.set_yticklabels([x for x in classes.keys()])

# %%
predictions = []
real_labels = []
wells = []
for i in tqdm(validation.index):
    filename = featdir + "{}_{}_{}.npz"
    filename = filename.format(
        validation.loc[i, "Metadata_Plate"], 
        validation.loc[i, "Metadata_Well"], 
        validation.loc[i, "Metadata_Site"]
    )
    with open(filename, "rb") as data:
        info = np.load(data)
        predictions.append(info["f"])
        label = validation.loc[i, "Compound_Concentration"]
        real_labels.append([classes[label]]*info["f"].shape[0])
        wells.append( validation.loc[i, "Metadata_Plate"] + "_" + validation.loc[i, "Metadata_Well"])

# %%
total_single_cells = 0
for i in range(len(predictions)):
    total_single_cells += predictions[i].shape[0]
    
print("Total images",len(predictions),predictions[0].shape)
print("Total single cells:", total_single_cells)

# %% [markdown]
# # Single cell classification accuracy

# %%
correct = 0
y_true = []
y_pred = []
for i in range(len(predictions)):
    for j in range(predictions[i].shape[0]):
        pred = np.argmax(predictions[i][j])
        if pred == real_labels[i][j]:
            correct += 1
        y_true.append(real_labels[i][j])
        y_pred.append(pred)

# %%
print("Correctly classified single cells:", 100*(correct / total_single_cells), "%")

# %%
show_confusion_matrix(y_true, y_pred, classes)

# %% [markdown]
# # Image level classification accuracy

# %%
correct = 0
y_true = []
y_pred = []
for i in range(len(predictions)):
    aggregated = np.mean(predictions[i], axis=0)
    pred = np.argmax(aggregated)
    if pred == real_labels[i][0]:
        correct += 1
    y_true.append(real_labels[i][0])
    y_pred.append(pred)

# %%
print("Correctly classified images:", 100*(correct / len(predictions)), "%")

# %%
show_confusion_matrix(y_true, y_pred, classes)

# %% [markdown]
# # Well level classification accuracy

# %%
well_predictions = {}
well_labels = {}
for i in range(len(predictions)):
    try: well_predictions[wells[i]].append(predictions[i])
    except: well_predictions[wells[i]] = [predictions[i]]
    well_labels[wells[i]] = real_labels[i][0]

# %%
well_predictions = {k: np.mean(np.concatenate(well_predictions[k]), axis=0) for k in well_predictions.keys()}

# %%
correct = 0
y_true = []
y_pred = []
for k in well_predictions.keys():
    pred = np.argmax(well_predictions[k])
    if pred == well_labels[k]:
        correct += 1
    y_true.append(well_labels[k])
    y_pred.append(pred)

# %%
print("Correctly classified wells:", 100*(correct / len(well_predictions)), "%")

# %%
show_confusion_matrix(y_true, y_pred, classes)
